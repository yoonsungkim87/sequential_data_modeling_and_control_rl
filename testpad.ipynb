# %%
import virtual_env
env = virtual_env.scrEnv(1000)
env.reset()
#o, r, done, info = env.step(env.action_space.sample())
o, r, done, info = env.step(2)
print(o,r)
i = 0
while not done:
    #env.render()
    i += 1
    o, r, done, info = env.step(0) # take a random action
    print(i,o,r)
# Out:
# Using TensorFlow backend.
# > Compilation Time :  0.0169830322265625
# [ 80.383098     8.33752721   0.86548435] 1.0
# 1 [ 76.92864233   6.38717625   1.02732486] 1.0
# 2 [ 69.66615971   6.27408539   1.32731008] 1.0
# 3 [ 63.32774883   7.82166843   1.00239208] 1.0
# 4 [ 66.1925826    8.52903485   1.10658716] 1.0
# 5 [ 60.65253353  11.81000642   1.72154874] 1.0
# 6 [ 66.48021687  10.52560901   1.58618309] 1.0
# 7 [ 67.86397977   9.36117048   1.42428751] 1.0
# 8 [ 82.36275503   9.48233508   2.02751879] 1.0
# 9 [ 76.95550082   7.45881912   1.19163988] 1.0
# 10 [ 73.91229861   6.04796606   1.36669662] 1.0
# 11 [ 75.8656313    7.12722199   1.19721069] 1.0
# 12 [ 75.92942514   7.68645249   1.53733244] 1.0
# 13 [ 62.29968727   7.2051625    1.20730078] 1.0
# 14 [ 59.17022067   8.21804376   1.14203251] 1.0
# 15 [ 74.60649692   7.7059411    1.27516949] 1.0
# 16 [ 67.07908653   6.57083909   1.13467941] 1.0
# 17 [ 61.22475443   8.19325157   1.36838573] 1.0
# 18 [ 59.72938918   7.77303547   1.41799884] 1.0
# 19 [ 66.66798381   8.99268114   1.59551739] 1.0
# 20 [ 63.21994783   4.86652722   1.54165138] 1.0
# 21 [ 57.61677671   7.63750871   1.33997695] 1.0
# 22 [ 47.21132943  24.84733506   1.79330834] 0.0

# %%
env.reset()
#o, r, done, info = env.step(env.action_space.sample())
o, r, done, info = env.step(2)
print(o,r)
i = 0
while not done:
    #env.render()
    i += 1
    o, r, done, info = env.step(8) # take a random action
    print(i,o,r)
# Out:
# [ 80.383098     8.33752721   0.86548435] 1.0
# 1 [ 78.00064223   6.439025     1.02222405] 1.0
# 2 [ 71.01789297   6.50948      1.3127202 ] 1.0
# 3 [ 66.63084857   8.19424254   0.99332172] 1.0
# 4 [ 73.43076608   8.80424001   1.07685803] 1.0
# 5 [ 67.18703499  13.6254208    1.68953577] 1.0
# 6 [ 83.04277693  12.71087636   1.46910521] 1.0
# 7 [ 90.7143895   10.8615516    1.43121011] 1.0
# 8 [ 87.35326349  11.63326174   1.82636144] 1.0
# 9 [ 93.94022029   9.72437518   1.09084016] 1.0
# 10 [ 91.42237753   6.54915853   1.19580187] 1.0
# 11 [ 84.34458145   8.77597245   1.08463452] 1.0
# 12 [ 83.43590189  11.23696189   1.04773133] 1.0
# 13 [ 80.00182931  10.38868073   0.93966287] 1.0
# 14 [ 82.88980215   7.46627399   1.18486384] 1.0
# 15 [ 83.77504443   6.13692649   1.18277249] 1.0
# 16 [ 92.34624937   4.74215463   0.92597687] 1.0
# 17 [ 83.3462294    8.37503941   1.07942814] 1.0
# 18 [ 95.95289662  14.58745291   1.70777139] 1.0
# 19 [ 110.7945535     6.3903926     1.27177651] 1.0
# 20 [ 110.38193024    5.52973373    1.54932826] 1.0
# 21 [ 93.59907549   5.3110052    0.91538702] 1.0
# 22 [ 80.58294078  10.62312892   1.62851593] 1.0
# 23 [ 84.35778131  13.41412319   0.92572511] 1.0
# 24 [ 95.74304908  20.51357003   0.9829195 ] 0.0

# %%
for _ in range(1):
    print(env.step(0) )# take a random action
# Out:
# (array([ 0.05711411, -0.04215879,  0.03183727,  0.11868003]), 1.0, False, {})
